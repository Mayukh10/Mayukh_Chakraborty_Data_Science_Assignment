# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('')

# %%
data = pd.read_csv('/content/Transactions.csv')

# %%
data.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue   Price
# 0      300.68  300.68
# 1      300.68  300.68
# 2      300.68  300.68
# 3      601.36  300.68
# 4      902.04  300.68
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Quantity'].plot(kind='hist', bins=20, title='Quantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['TotalValue'].plot(kind='hist', bins=20, title='TotalValue')
# ...

# %%
data.tail()
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue   Price
# 995      459.86  459.86
# 996     1379.58  459.86
# 997     1839.44  459.86
# 998      919.72  459.86
# 999      459.86  459.86

# %%
data.columns
# Out:
# Index(['TransactionID', 'CustomerID', 'ProductID', 'TransactionDate',
#        'Quantity', 'TotalValue', 'Price'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 7)

# %%
missing = data.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
# Check if 'missing' is empty before plotting
if not missing.empty:
    missing.plot.bar()
else:
    print("No missing values to plot.")
# Out:
# No missing values to plot.

# %%
data['Price'].describe()
# Out:
# count    1000.00000
# mean      272.55407
# std       140.73639
# min        16.08000
# 25%       147.95000
# 50%       299.93000
# 75%       404.40000
# max       497.76000
# Name: Price, dtype: float64

# %%
 sns.set(rc={'figure.figsize':(12,8)})
 sns.distplot(data['Price'], bins = 20);
# Out:
# <ipython-input-27-d09dab4f2cd6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'], bins = 20);

# %%
sns.kdeplot(data['Price'], shade=True);
# Out:
# <ipython-input-26-c6334c385574>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Price'], shade=True);

# %%
data['Price'].describe()
# Out:
# count    1000.00000
# mean      272.55407
# std       140.73639
# min        16.08000
# 25%       147.95000
# 50%       299.93000
# 75%       404.40000
# max       497.76000
# Name: Price, dtype: float64

# %%
numeric_features = data.select_dtypes(include=[np.number])
numeric_features.columns
# Out:
# Index(['Quantity', 'TotalValue', 'Price'], dtype='object')

# %%
catergorical_features = data.select_dtypes(exclude=[np.number])
catergorical_features.columns
# Out:
# Index(['TransactionID', 'CustomerID', 'ProductID', 'TransactionDate'], dtype='object')

# %%
correlation = numeric_features.corr()
print(correlation['Price'].sort_values(ascending=False), '\n')
# Out:
# Price         1.000000
# TotalValue    0.722714
# Quantity     -0.009378
# Name: Price, dtype: float64

# %%
f , ax = plt.subplots(figsize=(14,12))

plt.title('Correlation of Numeric Features with Price', y=1.05, size=15)
sns.heatmap(correlation, square = True, vmax=0.8);

# %%
k = 11
cols = correlation.nlargest(k, 'Price')['Price'].index
print(cols)
cm = np.corrcoef(data[cols].values.T)
f , ax=plt.subplots(figsize=(14,12))
sns.heatmap(cm, vmax=.8, linewidths=0.01, cmap="viridis", square=True, annot=True, linecolor="white", xticklabels=cols.tolist(), annot_kws={'size':12}, yticklabels=cols)
# Out:
# Index(['Price', 'TotalValue', 'Quantity'], dtype='object')
# <Axes: >

# %%
sns.scatterplot(x='Price', y='Quantity', data=data);

# %%
sns.regplot(x='Price', y='Quantity', data=data, fit_reg=False);

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
# Access individual subplots using indices
ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()

sns.regplot(x='Price', y='Quantity', data=data, ax=ax1)
sns.regplot(x='Price', y='TotalValue', data=data, ax=ax2)
# Out:
# <Axes: xlabel='Price', ylabel='TotalValue'>

# %%
sns.boxplot(x=data['Price']);

# %%
f, ax = plt.subplots(figsize=(16, 10))
fig = sns.boxplot(x="Quantity", y="Price", data=data)
fig.axis(ymin=0, ymax=800000);
xt = plt.xticks(rotation=45)

# %%
data['Price'].describe()
# Out:
# count    1000.00000
# mean      272.55407
# std       140.73639
# min        16.08000
# 25%       147.95000
# 50%       299.93000
# 75%       404.40000
# max       497.76000
# Name: Price, dtype: float64

# %%
first_quartile = data['Price'].quantile(0.25)
third_quartile = data['Price'].quantile(0.75)
iqr = third_quartile - first_quartile

# %%
new_boundary = 3 * iqr

# %%
data.drop(data[data['Price']>new_boundary].index,axis = 0, inplace = True)

# %%
data.shape
# Out:
# (1000, 7)
